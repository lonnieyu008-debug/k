# %%
"CityU"[0]
# Out:
# 'C'

# %%
s = "CityU"
s[0]
# Out:
# 'C'

# %%
a = "   cityu   hk    "

# %%
a.rstrip()
# Out:
# '   cityu   hk'

# %%
a.lstrip()
# Out:
# 'cityu   hk    '

# %%
a.strip()
# Out:
# 'cityu   hk'

# %%
"CityU hku UST".count("U")
# Out:
# 2

# %%
"CityU hku UST".lower().title().count("u")
# Out:
# 2

# %%
"CityU hku UST".lower().title()
# Out:
# 'Cityu Hku Ust'

# %%
print("ab")
# Out:
# ab

# %%
print("a\tb")
# Out:
# a	b

# %%
len("a        b")
# Out:
# 10

# %%
len("a\tb")
# Out:
# 3

# %%
print("a\nb")
# Out:
# a
# b

# %%
print("a\n\nb")
# Out:
# a
#
# b

# %%
len("a\n\nb")
# Out:
# 4

# %%
len("a\nb")
# Out:
# 3

# %%
print(')
# Out:
#   Cell In[19], line 1
#     print(')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("'")
# Out:
# '

# %%
print("\'")
# Out:
# '

# %%
print(""")
# Out:
#   Cell In[25], line 1
#     print(""")
#           ^
# _IncompleteInputError: incomplete input

# %%
print("\"")
# Out:
# "

# %%
print("\")
# Out:
#   Cell In[27], line 1
#     print("\")
#           ^
# SyntaxError: unterminated string literal (detected at line 1); perhaps you escaped the end quote?

# %%
print("\\")
# Out:
# \

# %%
print("\\\")
# Out:
#   Cell In[29], line 1
#     print("\\\")
#           ^
# SyntaxError: unterminated string literal (detected at line 1); perhaps you escaped the end quote?

# %%
print("\\\\")
# Out:
# \\

# %%
len("\\\\")
# Out:
# 2

# %%
print("\\\t\n\"")
# Out:
# \
# "

# %%
len("\\\t\n\"")
# Out:
# 4

# %%
name = "Tom"
age = "18"
print(f"{name} is {age}!")
# Out:
# Tom is 18!

# %%
print("name is age!")
# Out:
# name is age!

# %%
s = "{} is {:d}."
print(s.format("Tom","a dog"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 s = "{} is {:d}."
# ----> 2 print(s.format("Tom","a dog"))
#
# ValueError: Unknown format code 'd' for object of type 'str'

# %%
s = "{} is {:d}."
print(s.format("Tom",18))
# Out:
# Tom is 18.

# %%
s = "{} is {:d}."
print(s.format(88555,18))
# Out:
# 88555 is 18.

# %%
s = "{0:s} is {1:d}."
print(s.format("Tom",18))
# Out:
# Tom is 18.

# %%
s = "{:s} is {:d}."
print(s.format(85555,18))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 s = "{:s} is {:d}."
# ----> 2 print(s.format(85555,18))
#
# ValueError: Unknown format code 's' for object of type 'int'

# %%
a = "The price of {} is ${:.2f}"
print(a.format("an apple",2.56325452))
# Out:
# The price of an apple is $2.56

# %%
a = "The price of {} is ${:.2f}"
print(a.format("an apple","Steve Jobs"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 2
#       1 a = "The price of {} is ${:.2f}"
# ----> 2 print(a.format("an apple","Steve Jobs"))
#
# ValueError: Unknown format code 'f' for object of type 'str'

# %%
print("{:>5s}${:<5n}".format("a",3))
# Out:
#     a$3

# %%
print("{:<3}{:20}{:>3}".format(1,"Tom Hanks", 67))
print("{:<3}{:20}{:>3}".format(2, "Ming Wai Lau", 89))
# Out:
# 1  Tom Hanks            67
# 2  Ming Wai Lau         89

# %%
lst = ["CityU", 1984]

# %%
lst[0]
# Out:
# 'CityU'

# %%
lst[0][1] # "cityu"[1]
# Out:
# 'i'

# %%
lst[1][1] # numbers do not have index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 lst[1][1]
#
# TypeError: 'int' object is not subscriptable

# %%
lst.index("CityU")
# Out:
# 0

# %%
lst.index("C")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 lst.index("C")
#
# ValueError: 'C' is not in list

# %%
lst = [1,3,"10"]

# %%
max(lst)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 max(lst)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
min(lst)
# Out:
# 1

# %%
a = [1,3,2]
b = [2,6,2]

# %%
sorted(a) # will generate a new list but do not change the original list
# Out:
# [1, 2, 3]

# %%
print(a)
# Out:
# [1, 3, 2]

# %%
b.sort() # sort() will apply the change to the original list directly

# %%
print(b)
# Out:
# [2, 2, 6]

# %%
x = "a#b#c#d"

# %%
x.split()
# Out:
# ['a#b#c#d']

# %%
x.split("#")
# Out:
# ['a', 'b', 'c', 'd']

# %%
"".join(['a', 'b', 'c', 'd'])
# Out:
# 'abcd'

# %%
" ".join(['a', 'b', 'c', 'd'])
# Out:
# 'a b c d'

# %%
"$".join(['a', 'b', 'c', 'd'])
# Out:
# 'a$b$c$d'

# %%
", ".join(['a', 'b', 'c', 'd'])
# Out:
# 'a, b, c, d'
